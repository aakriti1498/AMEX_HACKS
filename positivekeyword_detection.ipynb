# %%
import csv
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = "C:/Users/Ishita Jain/Desktop/amex/Tweets.csv"

# %%
import pandas
result = pandas.read_csv(file)
print(result)
# Out:
#                  tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0      570306133677760513           neutral                        1.0000
# 1      570301130888122368          positive                        0.3486
# 2      570301083672813571           neutral                        0.6837
# 3      570301031407624196          negative                        1.0000
# 4      570300817074462722          negative                        1.0000
# 5      570300767074181121          negative                        1.0000
# 6      570300616901320704          positive                        0.6745
# 7      570300248553349120           neutral                        0.6340
# 8      570299953286942721          positive                        0.6559
# 9      570295459631263746          positive                        1.0000
# 10     570294189143031808           neutral                        0.6769
# 11     570289724453216256          positive                        1.0000
# ...

# %%
result.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# ...

# %%
result.columns
# Out:
# Index(['tweet_id', 'airline_sentiment', 'airline_sentiment_confidence',
#        'negativereason', 'negativereason_confidence', 'airline',
#        'airline_sentiment_gold', 'name', 'negativereason_gold',
#        'retweet_count', 'text', 'tweet_coord', 'tweet_created',
#        'tweet_location', 'user_timezone'],
#       dtype='object')

# %%
tweets = result.text

# %%
count=[]
keywords=[]

# %%
for p in tweets:
    count=p.split()
    for word in count:
        keywords.append(word)

# %%
keywords
# Out:
# ['@VirginAmerica',
#  'What',
#  '@dhepburn',
#  'said.',
#  '@VirginAmerica',
#  'plus',
#  "you've",
#  'added',
#  'commercials',
#  'to',
#  'the',
#  'experience...',
#  'tacky.',
#  '@VirginAmerica',
#  'I',
#  "didn't",
#  'today...',
#  'Must',
#  'mean',
#  'I',
#  'need',
#  'to',
#  'take',
#  'another',
#  'trip!',
#  '@VirginAmerica',
#  "it's",
#  'really',
#  'aggressive',
#  'to',
#  'blast',
#  'obnoxious',
#  '"entertainment"',
#  'in',
#  'your',
#  "guests'",
#  'faces',
#  '&amp;',
#  'they',
#  'have',
#  'little',
#  'recourse',
#  '@VirginAmerica',
#  'and',
#  "it's",
#  'a',
#  'really',
#  'big',
#  'bad',
#  'thing',
#  'about',
#  'it',
#  '@VirginAmerica',
#  'seriously',
#  'would',
#  'pay',
#  '$30',
#  'a',
#  'flight',
#  'for',
#  'seats',
#  'that',
#  "didn't",
#  'have',
#  'this',
#  'playing.',
#  "it's",
#  'really',
#  'the',
#  'only',
#  'bad',
#  'thing',
#  'about',
#  'flying',
#  'VA',
#  '@VirginAmerica',
#  'yes,',
#  'nearly',
# ...

# %%
positive_words = pd.read_csv('C:/Users/Ishita Jain/Desktop/positive-words.txt', sep=" ", header=None)

# %%
positive_words
# Out:
#                     0
# 0                  a+
# 1              abound
# 2             abounds
# 3           abundance
# 4            abundant
# 5          accessable
# 6          accessible
# 7             acclaim
# 8           acclaimed
# 9         acclamation
# 10           accolade
# 11          accolades
# 12      accommodative
# 13       accomodative
# 14         accomplish
# 15       accomplished
# 16     accomplishment
# 17    accomplishments
# 18           accurate
# 19         accurately
# 20         achievable
# 21        achievement
# 22       achievements
# 23         achievible
# 24             acumen
# 25          adaptable
# 26           adaptive
# 27           adequate
# 28         adjustable
# 29          admirable
# ...               ...
# 1976            witty
# 1977              won
# 1978           wonder
# 1979        wonderful
# 1980      wonderfully
# 1981        wonderous
# 1982      wonderously
# 1983          wonders
# 1984         wondrous
# ...

# %%
words=set()

# %%
for a in positive_words[0]:
    words.add(a)

# %%
words
# Out:
# {'loyal',
#  'honorable',
#  'conciliatory',
#  'assurances',
#  'lovely',
#  'unabashedly',
#  'fruitful',
#  'protective',
#  'beautifully',
#  'breakthrough',
#  'fresh',
#  'unrestricted',
#  'rectify',
#  'preferring',
#  'assuredly',
#  'piety',
#  'heroize',
#  'sharp',
#  'swanky',
#  'lustrous',
#  'fearlessly',
#  'vigilant',
#  'righten',
#  'exalted',
#  'exultation',
#  'strong',
#  'fecilitous',
#  'glowing',
#  'great',
#  'achievements',
#  'serene',
#  'remarkably',
#  'amazed',
#  'neatest',
#  'praising',
#  'lyrical',
#  'savior',
#  'faster',
#  'astonishing',
#  'luxuriate',
#  'cherish',
#  'coolest',
#  'radiance',
#  'reputation',
#  'zippy',
#  'hallmark',
#  'altruistic',
#  'fearless',
#  'inspiring',
#  'notably',
#  'painless',
#  'vivacious',
#  'satisfactory',
#  'enraptured',
#  'trusting',
#  'audibly',
#  'improvement',
#  'reliably',
#  'unreal',
#  'marvellous',
#  'autonomous',
#  'extraordinarily',
#  'contribution',
#  'reaffirmation',
# ...

# %%
len(words)
# Out:
# 2006

# %%
positive_words[0]
# Out:
# 0                    a+
# 1                abound
# 2               abounds
# 3             abundance
# 4              abundant
# 5            accessable
# 6            accessible
# 7               acclaim
# 8             acclaimed
# 9           acclamation
# 10             accolade
# 11            accolades
# 12        accommodative
# 13         accomodative
# 14           accomplish
# 15         accomplished
# 16       accomplishment
# 17      accomplishments
# 18             accurate
# 19           accurately
# 20           achievable
# 21          achievement
# 22         achievements
# 23           achievible
# 24               acumen
# 25            adaptable
# 26             adaptive
# 27             adequate
# 28           adjustable
# 29            admirable
#              ...
# 1976              witty
# 1977                won
# 1978             wonder
# 1979          wonderful
# 1980        wonderfully
# 1981          wonderous
# 1982        wonderously
# ...

# %%
positive_comments=[]

# %%
positive_dict
# Out:
# [['', 0]]

# %%
for word in keywords:
    if word in words:
        print("positive comment :"+ word)
        for b in positive_dict:
                if (b[0]==word):
                    print("already there : "+ word)
                    b[1]=b[1]+1
                else:
                    positive_dict.append([word,1])
# Out:
#   File "<ipython-input-24-552597729630>", line 4
#     for b in positive_dict:
#     ^
# IndentationError: unexpected indent

# %%
positive_dict
# Out:
# [['', 0]]

# %%
len(positive_dict)
# Out:
# 1

# %%
positive_dict=[["",0]]
for word in keywords:
    if word in words:
        flag=0
        if(len(positive_dict)>1):
            for b in positive_dict:
                if(b[0]==word):
                    b[1]=b[1]+1;
                    print("positive comment : ",word)
                    print("b[0] is already there : ",word)
                    flag=1
            if(flag==0)  :
                positive_dict.append([word,1])
                
                    
                    
        else:
            positive_dict.append([word,1])
# Out:
# positive comment :  great
# b[0] is already there :  great
# positive comment :  love
# b[0] is already there :  love
# positive comment :  good
# b[0] is already there :  good
# positive comment :  great
# b[0] is already there :  great
# positive comment :  good
# b[0] is already there :  good
# positive comment :  excited
# b[0] is already there :  excited
# positive comment :  great
# b[0] is already there :  great
# positive comment :  love
# b[0] is already there :  love
# positive comment :  great
# b[0] is already there :  great
# positive comment :  great
# b[0] is already there :  great
# positive comment :  like
# b[0] is already there :  like
# positive comment :  like
# b[0] is already there :  like
# positive comment :  elevate
# b[0] is already there :  elevate
# positive comment :  elevate
# b[0] is already there :  elevate
# positive comment :  like
# b[0] is already there :  like
# positive comment :  interesting
# b[0] is already there :  interesting
# ...

# %%
positive_dict
# Out:
# [['', 0],
#  ['good', 204],
#  ['leading', 8],
#  ['pretty', 37],
#  ['better', 141],
#  ['great', 205],
#  ['excited', 15],
#  ['amazingly', 1],
#  ['available', 73],
#  ['love', 168],
#  ['free', 106],
#  ['amazing', 50],
#  ['cool', 27],
#  ['elevate', 4],
#  ['prefer', 7],
#  ['support', 24],
#  ['win', 16],
#  ['wow', 14],
#  ['entertaining', 2],
#  ['winning', 5],
#  ['award', 38],
#  ['fine', 18],
#  ['awesome', 47],
#  ['like', 408],
#  ['correct', 23],
#  ['best', 129],
#  ['interesting', 4],
#  ['friendly', 14],
#  ['comfortable', 5],
#  ['beautiful', 10],
#  ['right', 136],
#  ['reputation', 3],
#  ['compatible', 2],
#  ['outstanding', 7],
#  ['complimentary', 6],
#  ['afford', 13],
#  ['super', 28],
#  ['helpful', 58],
#  ['thank', 269],
#  ['happy', 61],
#  ['faster', 12],
#  ['work', 166],
#  ['goodness', 1],
#  ['pros', 1],
#  ['refund', 98],
#  ['nicely', 2],
#  ['fun', 20],
#  ['helping', 38],
#  ['trust', 10],
#  ['easy', 26],
#  ['painless', 2],
# ...

# %%
len(positive_dict)
# Out:
# 421

# %%
xvar=[]
yvar=[]
xlabel=[]

# %%
for i in range(len(positive_dict)):
    xvar.append(i)

# %%
for c in positive_dict:
    yvar.append(c[1])
    xlabel.append(c[0])

# %%
xlabel
# Out:
# ['',
#  'good',
#  'leading',
#  'pretty',
#  'better',
#  'great',
#  'excited',
#  'amazingly',
#  'available',
#  'love',
#  'free',
#  'amazing',
#  'cool',
#  'elevate',
#  'prefer',
#  'support',
#  'win',
#  'wow',
#  'entertaining',
#  'winning',
#  'award',
#  'fine',
#  'awesome',
#  'like',
#  'correct',
#  'best',
#  'interesting',
#  'friendly',
#  'comfortable',
#  'beautiful',
#  'right',
#  'reputation',
#  'compatible',
#  'outstanding',
#  'complimentary',
#  'afford',
#  'super',
#  'helpful',
#  'thank',
#  'happy',
#  'faster',
#  'work',
#  'goodness',
#  'pros',
#  'refund',
#  'nicely',
#  'fun',
#  'helping',
#  'trust',
#  'easy',
#  'painless',
#  'improve',
#  'advantage',
#  'fav',
#  'hot',
#  'positive',
#  'loved',
#  'helped',
#  'promised',
#  'lovely',
#  'soft',
#  'adore',
#  'glad',
#  'uphold',
#  'smooth',
#  'loyal',
#  'well',
#  'boost',
#  'recommend',
#  'swanky',
#  'superior',
#  'brilliant',
#  'brisk',
#  'favorite',
#  'excellent',
# ...

# %%
plt.xlabel('positive keywords')
plt.ylabel('frequency')
plt.title("POSITIVE REVIEWS")
plt.xticks(xvar[1:10],xlabel[1:10])
plt.plot(xvar[1:10],yvar[1:10])

# %%
plt.show()

# %%
tweets
# Out:
# 0                      @VirginAmerica What @dhepburn said.
# 1        @VirginAmerica plus you've added commercials t...
# 2        @VirginAmerica I didn't today... Must mean I n...
# 3        @VirginAmerica it's really aggressive to blast...
# 4        @VirginAmerica and it's a really big bad thing...
# 5        @VirginAmerica seriously would pay $30 a fligh...
# 6        @VirginAmerica yes, nearly every time I fly VX...
# 7        @VirginAmerica Really missed a prime opportuni...
# 8          @virginamerica Well, I didn't…but NOW I DO! :-D
# 9        @VirginAmerica it was amazing, and arrived an ...
# 10       @VirginAmerica did you know that suicide is th...
# 11       @VirginAmerica I &lt;3 pretty graphics. so muc...
# 12       @VirginAmerica This is such a great deal! Alre...
# 13       @VirginAmerica @virginmedia I'm flying your #f...
# 14                                  @VirginAmerica Thanks!
# 15           @VirginAmerica SFO-PDX schedule is still MIA.
# ...
